# %%
import pandas as pd
import numpy as np

# %%
usecols=['identifier','port_of_unlading',]

# %%
dtype={'identifier':str,'port_of_unlading':str,}

# %%
data = pd.read_csv('BofL6country.csv')
# Out:
# C:\Users\raymo\Anaconda3\envs\topicModeling\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3825317 entries, 0 to 3825316
# Data columns (total 31 columns):
# identifier                         float64
# trade_update_date                  object
# run_date                           object
# vessel_name                        object
# port_of_unlading                   object
# estimated_arrival_date             object
# foreign_port_of_lading             object
# record_status_indicator            object
# place_of_receipt                   object
# port_of_destination                object
# foreign_port_of_destination        object
# secondary_notify_party_1           object
# actual_arrival_date                object
# consignee_name                     object
# consignee_address                  object
# consignee_contact_name             object
# consignee_comm_number_qualifier    object
# consignee_comm_number              object
# shipper_party_name                 object
# shipper_address                    object
# ...

# %%
data.head()
# Out:
#      identifier    trade_update_date             run_date  \
# 0  2.018022e+12  2018-02-06T00:00:00  2018-02-21T00:00:00
# 1  2.018022e+12  2018-02-17T00:00:00  2018-02-24T00:00:00
# 2  2.018023e+12  2018-02-01T00:00:00  2018-02-26T00:00:00
# 3  2.018023e+12  2018-02-02T00:00:00  2018-02-26T00:00:00
# 4  2.018030e+12  2018-02-05T00:00:00  2018-03-02T00:00:00
#
#             vessel_name                          port_of_unlading  \
# 0      YM ENLIGHTENMENT                         Norfolk, Virginia
# 1          MSC SAVANNAH  New York/Newark Area, Newark, New Jersey
# 2  PHILADELPHIA EXPRESS                            Houston, Texas
# 3           APL BELGIUM                       Oakland, California
# 4          MSC VALENCIA                       Baltimore, Maryland
#
#   estimated_arrival_date      foreign_port_of_lading record_status_indicator  \
# 0    2018-02-18T00:00:00              Anvers,Belgium                     New
# ...

# %%
data.iloc[0]
# Out:
# identifier                                                               2.01802e+12
# trade_update_date                                                2018-02-06T00:00:00
# run_date                                                         2018-02-21T00:00:00
# vessel_name                                                         YM ENLIGHTENMENT
# port_of_unlading                                                   Norfolk, Virginia
# estimated_arrival_date                                           2018-02-18T00:00:00
# foreign_port_of_lading                                                Anvers,Belgium
# record_status_indicator                                                          New
# place_of_receipt                                                             ANTWERP
# port_of_destination                                                              NaN
# foreign_port_of_destination                                                      NaN
# ...

# %%
data.dtypes
# Out:
# identifier                         float64
# trade_update_date                   object
# run_date                            object
# vessel_name                         object
# port_of_unlading                    object
# estimated_arrival_date              object
# foreign_port_of_lading              object
# record_status_indicator             object
# place_of_receipt                    object
# port_of_destination                 object
# foreign_port_of_destination         object
# secondary_notify_party_1            object
# actual_arrival_date                 object
# consignee_name                      object
# consignee_address                   object
# consignee_contact_name              object
# consignee_comm_number_qualifier     object
# consignee_comm_number               object
# shipper_party_name                  object
# shipper_address                     object
# shipper_contact_name                object
# shipper_comm_number_qualifier       object
# ...

# %%
data.columns[26]
# Out:
# 'description_text'

# %%
data['harmonized_number'].apply(lambda x: not str(x).isnumeric() and not bool(x)).sort_values()
# Out:
# 0          False
# 2550203    False
# 2550204    False
# 2550205    False
# 2550206    False
# 2550207    False
# 2550208    False
# 2550209    False
# 2550210    False
# 2550211    False
# 2550212    False
# 2550213    False
# 2550214    False
# 2550215    False
# 2550216    False
# 2550217    False
# 2550218    False
# 2550219    False
# 2550220    False
# 2550221    False
# 2550222    False
# 2550223    False
# 2550224    False
# 2550225    False
# 2550226    False
# 2550227    False
# 2550202    False
# 2550228    False
# 2550201    False
# 2550199    False
#            ...
# 1275114    False
# 1275113    False
# 1275087    False
# 1275088    False
# 1275089    False
# 1275090    False
# 1275091    False
# 1275092    False
# 1275093    False
# 1275094    False
# 1275095    False
# 1275096    False
# 1275097    False
# 1275098    False
# 1275143    False
# 1275099    False
# 1275101    False
# 1275102    False
# 1275103    False
# 1275104    False
# 1275105    False
# ...

# %%
data.iloc[2550203]
# Out:
# identifier                                                               2.01801e+12
# trade_update_date                                                2018-01-01T00:00:00
# run_date                                                         2018-01-15T00:00:00
# vessel_name                                                             YM EVOLUTION
# port_of_unlading                                                   Norfolk, Virginia
# estimated_arrival_date                                           2018-01-07T00:00:00
# foreign_port_of_lading                       Bremerhaven,Federal Republic of Germany
# record_status_indicator                                                          New
# place_of_receipt                                                     BREMERHAVEN, DE
# port_of_destination                                              St. Louis, Missouri
# foreign_port_of_destination                                                      NaN
# ...
