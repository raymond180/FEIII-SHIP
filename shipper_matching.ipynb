# %%
import pandas as pd
import numpy as np

# %%
usecols = ['identifier', 'shipper_party_name', 'shipper_party_address_1',
       'shipper_party_address_2', 'shipper_party_address_3',
       'shipper_party_address_4', 'city', 'state_province', 'zip_code',
       'country_code']

# %%
dtype = {'identifier':str,'shipper_party_name':str, 'shipper_party_address_1':str,
       'shipper_party_address_2':str, 'shipper_party_address_3':str,
       'shipper_party_address_4':str, 'city':'category', 'state_province':'category', 'zip_code':'category',
       'country_code':'category'}

# %%
data = pd.read_csv('raw_data/2018/AMSShippers-2018.csv',usecols=usecols,dtype=dtype)

# %%
data['shipper_party_name'].value_counts().head()
# Out:
# ORIENT EXPRESS CONTAINER CO., LTD.     48203
# HONOUR LANE SHIPPING LIMITED           33600
# BEIJING KANG JIE KONG INTERNATIONAL    28668
# DE WELL CONTAINER SHIPPING INC.        27913
# HECNY SHIPPING LIMITED                 24245
# Name: shipper_party_name, dtype: int64

# %%
data.loc[data['shipper_party_name'].str.contains('dhl',case=False,regex=False,na=False)]
# Out:
#              identifier                   shipper_party_name  \
# 186         20180101204   DHL GLOBAL FORWARDING MALAYSIA SDN
# 421         20180101520   DHL GLOBAL FORWARDING (CANADA) INC
# 615         20180101792             DHL ISC (HK) LIMITED O/B
# 822        201801011097  DHL GLOBAL FORWARDING CHINA COMPANY
# 1205       201801011590        DHL LOGISTICS PRIVATE LIMITED
# 1207       201801011592        DHL LOGISTICS PRIVATE LIMITED
# 1428       201801011866  DHL GLOBAL FORWARDING (CHINA) COMPA
# 1436       201801011883   DHL GLOBAL FORWARDING CHINA CO LTD
# 1630       201801012123   DHL GLOBAL FORWARDING CHINA CO LTD
# 2431       201801013145       DHL LOGISITICS (CAMBODIA) LTD.
# 2432       201801013146       DHL LOGISITICS (CAMBODIA) LTD.
# 2465       201801013186    DHL GLOBAL FORWARDING (CHINA) CO.
# 2477       201801013204   DHL GLOBAL FORWARDING MALAYSIA SDN
# 2544       201801013316             DHL ISC (HK) LIMITED O/B
# 2545       201801013317             DHL ISC (HK) LIMITED O/B
# 2546       201801013318             DHL ISC (HK) LIMITED O/B
# 2547       201801013319             DHL ISC (HK) LIMITED O/B
# 2548       201801013320             DHL ISC (HK) LIMITED O/B
# 2549       201801013321             DHL ISC (HK) LIMITED O/B
# 2636       201801013437                DHL GLOBAL FORWARDING
# 2801       201801013727                          DHL ISC O/B
# 2898       201801013878                           DHL ISC OB
# 3036       201801014082        DHL LOGISTICS (CAMBODIA) LTD,
# 3037       201801014083        DHL LOGISTICS (CAMBODIA) LTD,
# 3113       201801014184                              DHL ISC
# 3117       201801014191                              DHL ISC
# 3119       201801014193                              DHL ISC
# 3265       201801014389                DHL LOGISTICS PVT LTD
# 3333       201801014469  DHL GLOBAL FORWARDING (NETHERLANDS)
# 3344       201801014482   DHL GLOBAL FORWARDING MALAYSIA SDN
# ...                 ...                                  ...
# 11097143  2018051566585  DHL GLOBAL FORWARDING GMBH AS AGENT
# 11097151  2018051566594           DHL GLOBAL FORWARDING GMBH
# 11097950  2018051573174   DHL GLOBAL FORWARDING COLOMBIA SAS
# 11097966  2018051573190     DHL GLOBAL FORWARDING FRANCE SAS
# 11098130  2018051573357   DHL GLOBAL FORWARDING COLOMBIA SAS
# 11098131  2018051573358   DHL GLOBAL FORWARDING COLOMBIA SAS
# 11098146  2018051573374   DHL GLOBAL FORWARDING COLOMBIA SAS
# 11098173  2018051573412         DHL GLOBAL FORWARDING FRANCE
# 11098244  2018051573497     DHL GLOBAL FORWARDING FRANCE SAS
# 11098291  2018051573549     DHL GLOBAL FORWARDING FRANCE SAS
# 11099120  2018051574491     DHL GLOBAL FORWARDING ECUADOR SA
# 11099323  2018051574736     DHL GLOBAL FORWARDING FRANCE SAS
# 11099784  2018051575273      DHL GLOBAL FORWARDING PANAMA SA
# 11100186   201805165034               DHL ISC HONG KONG LTD.
# 11100259   201805165185   DHL GLOBAL FORWARDING CHINA CO LTD
# 11100966   201805166402           DHL GLOBAL FORWARDING GMBH
# 11100970   201805166406    DHL GLOBAL FORWARDING (AUSTRALIA)
# 11101435   201805167100   DHL GLOBAL FORWARDING VIETNAM CORP
# 11101449   201805167122        DHL GLOBAL FORWARDING PH INC.
# 11101524   201805167220    DHL GLOBAL FORWARDING (AUSTRALIA)
# 11101539   201805167240  DHL GLOBAL FORW. (BRAZIL) LOG. LTDA
# 11101540   201805167241  DHL GLOBAL FORW. (BRAZIL) LOG. LTDA
# 11101541   201805167242  DHL GLOBAL FORW. (BRAZIL) LOG. LTDA
# 11101608   201805167339  DHL GLOBAL FORWARDING (CHINA) COMPA
# 11102159  2018051611707   DHL GLOBAL FORWARDING CHINA CO LTD
# 11102280  2018051611864  DHL GLOBALFORWARDING(ITALY)SPAAS AG
# 11102358  2018051612061          DHL ISC (HONG KONG) LIMITED
# 11102360  2018051612067          DHL ISC (HONG KONG) LIMITED
# 11102365  2018051612108            DHL ISC HONG KONG LIMITED
# 11102409  2018051612185            DHL ISC HONG KONG LIMITED
#
#                       shipper_party_address_1  \
# 186        LEVEL 9, MCT TOWER ONE CITY, JALAN
# 421                     230 - 13091 VANIER PL
# 615        HONGKONG NEWCT DEVELOPMENT LIMITED
# 822       7F PHILIPS RESEARCH AND DEVELOPMENT
# 1205           REGUS BUSINESS CENTRE, 403-404
# 1207           REGUS BUSINESS CENTRE, 403-404
# 1428      7 FLOOR BUILDING A,PACIFIC PLAZA, N
# 1436                          SHENZHEN BRANCH
# 1630                          SHENZHEN BRANCH
# 2431                O/B HANA (CAMBODIA) I INC
# 2432      O/B MORNING GLORY GARMENT ENTERPRIS
# 2465                    LTD. ZHONGSHAN BRANCH
# 2477       LEVEL 9, MCT TOWER ONE CITY, JALAN
# 2544                   ACTONA HONGKONG B.V.I.
# 2545             GARDENART FURNITURE CO., LTD
# 2546       ZHONGSHAN NEW POWER FURNISHING LTD
# 2547             GOLDEN SHINE WOODEN CO., LTD
# 2548                MAN WAH (MACAO COMMERCIAL
# 2549            HOMEPOINT DEVELOPMENT LIMITED
# 2636                           (AUSTRIA) GMBH
# 2801                     PUNGKOOK CORPORATION
# 2898                         CY VINA CO., LTD
# 3036      O/B SIMONE ACC. COLLECTION (CAMBODI
# 3037      O/B LUEN THAI FOOTWEAR MACAO COMMER
# 3113                                        .
# 3117                                        .
# 3119                                        .
# 3265           101 A/B SILVER UTOPIA CARDINAL
# 3333                                     B.V.
# 3344       LEVEL 9, MCT TOWER ONE CITY, JALAN
# ...                                       ...
# 11097143                    FLUGHAFENALLEE 11
# 11097151                                    .
# 11097950        ACI 4120 /  NIT 860.030.380-2
# 11097966        AS AGENT FOR DANMAR LINES LTD
# 11098130        ACI 4120 /  NIT 860.030.380-2
# 11098131        ACI 4120 /  NIT 860.030.380-2
# 11098146        ACI 4120 /  NIT 860.030.380-2
# 11098173                            PORT 4118
# 11098244        AS AGENT FOR DANMAR LINES LTD
# 11098291                 O/B DANMAR LINES LTD
# 11099120  CTRO DE CONVENCIONES GUAYAQUIL CTRO
# 11099323            AS AGENT FOR DANMAR LINES
# 11099784  PARK INDUSTRIAL AND CORPORATE SOUTH
# 11100186    4/F EDGE,NOS.30-34 KWAI WING ROAD
# 11100259                      SHENZHEN BRANCH
# 11100966                                    .
# 11100970       PTY LTD AS AGENTS OF DANMAR LI
# 11101435    CHARM VIT TOWER 18TH FL ROOM 1801
# 11101449                  8F STAR CRUISES CTR
# 11101524       PTY LTD AS AGENTS OF DANMAR LI
# 11101539             CNPJ  10.228.777/0011-33
# 11101540             CNPJ  10.228.777/0011-33
# 11101541             CNPJ  10.228.777/0011-33
# 11101608  16/F ORIENT INTERNATIONAL FINANCE P
# 11102159                      SHENZHEN BRANCH
# 11102280  VIA DELLE INDUSTRIE 1POZZUOLO MARTE
# 11102358            4/F,30 34 KWAI WING ROAD,
# 11102360            4/F,30 34 KWAI WING ROAD,
# 11102365         4/F, 30 - 34 KWAI WING ROAD,
# 11102409         4/F, 30 - 34 KWAI WING ROAD,
#
#                       shipper_party_address_2  \
# 186                      SUBANG JAYA SELANGOR
# 421                                   V6V 2J1
# 615               ROOM 1103,HANG SENG MONGKOK
# 822                        SHENZHEN GD 518000
# 1205       4TH FLOOR, OPP:HDFC BANK, RAMNAGAR
# 1207       4TH FLOOR, OPP:HDFC BANK, RAMNAGAR
# 1428                         NINGBO ZJ 315001
# 1436      7F PHILIPS RESEARCH AND DEVELOPMENT
# 1630      7F PHILIPS RESEARCH AND DEVELOPMENT
# 2431      PHUM TRAPAING KRASANG, SANGKAT TRAP
# 2432      WILSON INDUSTRY PARK, BUILDING F, N
# 2465      RM 04 05, 16F. INTL FINANCE CENTER,
# 2477                     SUBANG JAYA SELANGOR
# 2544                   C/O ACTONA COMPANY A/S
# 2545        UNIT 703, XIN CHUANG JU BUILDING,
# 2546                   NO.2 JINSAN ROAD EAST,
# 2547        DAHUAN INDUSTRIAL AREA DALINGSHAN
# 2548                        OFFSHORE) LIMITED
# 2549          QIUCHANG TOWN,HUIYANG DISTRICT,
# 2636                WILHELM SPAZIER STRASSE 2
# 2801      53 DUNCHON-DAERO 457 BEON-GIL JUNGW
# 2898      LOT N, ROAD NO 1, LONG DUC INDUSTRI
# 3036            PHUM ANG, SANGKAT CHAOM CHAO,
# 3037      CO LTD. AVENIDA DA PRAIA GRANDE, NO
# 3113       279, GYEONGSU-DAERO UIWANG  437 KR
# 3117       5A, XUYEN A HIGH WAY, DI AN  72000
# 3119       LOT.89,STREET NO.6, SONG THAN 1 DI
# 3265         GRACIAS ROAD CHAKALA ANDHERI (E)
# 3333      RIDDERHAVEN 5 RIDDERKERK  2984 BT N
# 3344                     SUBANG JAYA SELANGOR
# ...                                       ...
# 11097143              BREMEN HB 28199 GERMANY
# 11097151              2651 BREMEN HB 28199 DE
# 11097950           AVENIDA CALLE 26 NO.102-20
# 11097966                        P.O. BOX 2651
# 11098130           AVENIDA CALLE 26 NO.102-20
# 11098131           AVENIDA CALLE 26 NO.102-20
# 11098146           AVENIDA CALLE 26 NO.102-20
# 11098173         4118 BLD DE L'EUROPE - BP 99
# 11098244                   P.O. BOX 2651 4002
# 11098291                        P.O. BOX 2651
# 11099120                GUAYAQUIL G   ECUADOR
# 11099323                         ZONE CARGO 4
# 11099784                   TOCUMEN 8   PANAMA
# 11100186        KWAI CHUNG, NEW TERRITORIES .
# 11100259  7F PHILIPS RESEARCH AND DEVELOPMENT
# 11100966  FLUGHAFENALLEE 11 BREMEN HB 28199 D
# 11100970       DDI:+61 39344 8391/ F:+61 3934
# 11101435    117 TRAN DUY HUNG STREET CAU GIAY
# 11101449       100 ANDREWS AVENUE NEW PORT CI
# 11101524       DDI:+61 39344 8391/ F:+61 3934
# 11101539   AV. CARLOS GOMES, 1340 - CONJ. 702
# 11101540   AV. CARLOS GOMES, 1340 - CONJ. 702
# 11101541   AV. CARLOS GOMES, 1340 - CONJ. 702
# 11101608                   SHANGHAI SH 200010
# 11102159  7F PHILIPS RESEARCH AND DEVELOPMENT
# 11102280    POZZUOLO MARTESANA MI 20060 ITALY
# 11102358    KWAI CHUNG, NEW TERRITORIES, HONG
# 11102360    KWAI CHUNG, NEW TERRITORIES, HONG
# 11102365  KWAI CHUNG, NEW TERRITORIES, HONGKO
# 11102409  KWAI CHUNG, NEW TERRITORIES, HONGKO
#
#                       shipper_party_address_3  \
# 186                                  MALAYSIA
# 421                                       NaN
# 615                 BUILDING,677 NATHAN ROAD,
# 822                                     CHINA
# 1205            VISAKHAPATNAM-530002.AP,INDIA
# 1207            VISAKHAPATNAM-530002.AP,INDIA
# 1428                                    CHINA
# 1436       BUILDING NO12 SHIHUA RD FUTIAN FTZ
# 1630       BUILDING NO12 SHIHUA RD FUTIAN FTZ
# 2431      KHAN POSENCHEY, PHNOM PENH, CAMBODI
# 2432       ROAD NO.4, PHUM PHSAR KOMBOL,SANGK
# 2465                     16, ZHONGSHAN SAN RD
# 2477                                 MALAYSIA
# 2544                   SMEDEGAARDVEJ 6A, TVIS
# 2545             NO.123 TI YU XI ROAD, TIANHE
# 2546                  SANJIAO TOWN, ZHONGSHAN
# 2547             TOWN DONGGUAN CITY GUANGDONG
# 2548           ALAMEDA DR. CARLOS D'ASSUMPCAO
# 2549         HUIZHOU CITY,GUANGDONG PROVINCE,
# 2636                                 SALZBURG
# 2801      SEONGNAM CITY, GYEONGGI-DO, SOUTH K
# 2898       TRA VINH CITY , TRA VINH PROVINCE,
# 3036      KHAN POSENCHEY, PHNOM PENH, CAMBODI
# 3037      EDIFICO DOS SERVICOS JURIDICOS DA C
# 3113                                      NaN
# 3117                                       VN
# 3119                             AN  72000 VN
# 3265                                   MUMBAI
# 3333                                        L
# 3344                                 MALAYSIA
# ...                                       ...
# 11097143                                  NaN
# 11097151                                  NaN
# 11097950                      BOGOTA COLOMBIA
# 11097966                                 4002
# 11098130                TEL 746.96.96, BOGOTA
# 11098131    TEL 746.96.96, BOGOTA COLOMBIA CO
# 11098146    TEL 746.96.96, BOGOTA COLOMBIA CO
# 11098173                    CRAYWICK 59279 FR
# 11098244                    BASEL SWITZERLAND
# 11098291                                 4002
# 11099120                                  NaN
# 11099323                                  NaN
# 11099784                                  NaN
# 11100186                            HONG KONG
# 11100259   BUILDING NO12 SHIHUA RD FUTIAN FTZ
# 11100966                                    E
# 11100970                                  NaN
# 11101435                           HANOI CITY
# 11101449              CYBERTOURISM ZONE PASAY
# 11101524                                  NaN
# 11101539                          AUXILIADORA
# 11101540                          AUXILIADORA
# 11101541                          AUXILIADORA
# 11101608                                CHINA
# 11102159   BUILDING NO12 SHIHUA RD FUTIAN FTZ
# 11102280                                  NaN
# 11102358             KONG O/B VARIOUS VENDORS
# 11102360             KONG O/B VARIOUS VENDORS
# 11102365     NG O/B OF AMERICAN PHIL TEXTILES
# 11102409                                NG --
#
#                       shipper_party_address_4                 city  \
# 186                                       NaN                  NaN
# 421                                       NaN         RICHMOND, BC
# 615                                       NaN                  NaN
# 822                                       NaN                  NaN
# 1205                                      NaN  91-8916630119   TEL
# 1207                                      NaN  91-8916630119   TEL
# 1428                                      NaN                  NaN
# 1436                                      NaN                  NaN
# 1630                                      NaN                  NaN
# 2431                                      NaN  855-23216104    TEL
# 2432                                      NaN  855-23216104    TEL
# 2465                                      NaN                  NaN
# 2477                                      NaN                  NaN
# 2544                                      NaN                  NaN
# 2545                                      NaN                  NaN
# 2546                                      NaN                  NaN
# 2547                                      NaN                  NaN
# 2548                                      NaN                  NaN
# 2549                                      NaN                  NaN
# 2636                                      NaN  43-503450       TEL
# 2801                                      NaN                  NaN
# 2898                                      NaN                  NaN
# 3036                   TEL _ 855 23 988 980__                  NaN
# 3037      15 ANDAR A, EM MACAU. TEL_ 853-2835                  NaN
# 3113                                      NaN                  NaN
# 3117                                      NaN                  NaN
# 3119                                      NaN                  NaN
# 3265                                      NaN                  NaN
# 3333                                      NaN                  NaN
# 3344                                      NaN                  NaN
# ...                                       ...                  ...
# 11097143                                  NaN                  NaN
# 11097151                                  NaN                  NaN
# 11097950                   CO JOSE LUIS MONGE                  NaN
# 11097966                                  NaN                  NaN
# 11098130                             COLOMBIA                  NaN
# 11098131   JOSE LUIS MONGE TE  57 1 746.96.96                  NaN
# 11098146   JOSE LUIS MONGE TE  57 1 746.96.96                  NaN
# 11098173                                  NaN                  NaN
# 11098244                                  NaN                  NaN
# 11098291                                  NaN                  NaN
# 11099120                                  NaN                  NaN
# 11099323                                  NaN   27 RUE DE LA BELLE
# 11099784                                  NaN                  NaN
# 11100186                                  NaN                  NaN
# 11100259                                  NaN                  NaN
# 11100966                                  NaN                  NaN
# 11100970                                  NaN  MELBOURNE AIRPORT V
# 11101435                                  NaN  84-437737898    TEL
# 11101449                                  NaN                  NaN
# 11101524                                  NaN  MELBOURNE AIRPORT V
# 11101539   PORTO ALEGRE - PH  55 51 3327 3320                  NaN
# 11101540   PORTO ALEGRE - PH  55 51 3327 3320                  NaN
# 11101541   PORTO ALEGRE - PH  55 51 3327 3320                  NaN
# 11101608                                  NaN                  NaN
# 11102159                                  NaN  86-75522183251  TEL
# 11102280                                  NaN                  NaN
# 11102358                                  NaN  852-29766427    TEL
# 11102360                                  NaN  852-29766427    TEL
# 11102365                                  NaN  852-27436912    TEL
# 11102409                                  NaN  852-29766427    TEL
#
#          state_province  zip_code country_code
# 186                 NaN       NaN          NaN
# 421                  BC    V6V2J1           CA
# 615                 NaN       NaN          NaN
# 822                 NaN       NaN          NaN
# 1205                 EX  91-89166           30
# 1207                 EX  91-89166           30
# 1428                NaN       NaN          NaN
# 1436                NaN       NaN          NaN
# 1630                NaN       NaN          NaN
# 2431                 EX  855-2388           59
# 2432                 EX  855-2388           59
# 2465                NaN       NaN          NaN
# 2477                NaN       NaN          NaN
# 2544                NaN       NaN          NaN
# 2545                NaN       NaN          NaN
# 2546                NaN       NaN          NaN
# 2547                NaN       NaN          NaN
# 2548                NaN       NaN          NaN
# 2549                NaN       NaN          NaN
# 2636                 EX  43-50345           25
# 2801                NaN       NaN          NaN
# 2898                NaN       NaN          NaN
# 3036                NaN       NaN          NaN
# 3037                NaN       NaN          NaN
# 3113                NaN       NaN          NaN
# 3117                NaN       NaN          NaN
# 3119                NaN       NaN          NaN
# 3265                NaN       NaN          NaN
# 3333                NaN       NaN          NaN
# 3344                NaN       NaN          NaN
# ...                 ...       ...          ...
# 11097143            NaN       NaN          NaN
# 11097151            NaN       NaN          NaN
# 11097950            NaN       NaN          NaN
# 11097966            NaN       NaN          NaN
# 11098130            NaN       NaN          NaN
# 11098131            NaN       NaN          NaN
# 11098146            NaN       NaN          NaN
# 11098173            NaN       NaN          NaN
# 11098244            NaN       NaN          NaN
# 11098291            NaN       NaN          NaN
# 11099120            NaN       NaN          NaN
# 11099323            NaN     95976           FR
# 11099784            NaN       NaN          NaN
# 11100186            NaN       NaN          NaN
# 11100259            NaN       NaN          NaN
# 11100966            NaN       NaN          NaN
# 11100970             VI      3045           AU
# 11101435             EX  84-04377           37
# 11101449            NaN       NaN          NaN
# 11101524             VI      3045           AU
# 11101539            NaN       NaN          NaN
# 11101540            NaN       NaN          NaN
# 11101541            NaN       NaN          NaN
# 11101608            NaN       NaN          NaN
# 11102159             EX  86-75525           47
# 11102280            NaN       NaN          NaN
# 11102358             EX  852-2976           36
# 11102360             EX  852-2976           36
# 11102365             EX  852-2741           18
# 11102409             EX  852-2976           36
#
# [87254 rows x 10 columns]

# %% [markdown]
# ### Match company by TFIDF
# https://bergvca.github.io/2017/10/14/super-fast-string-matching.html

# %%
import re
def ngrams(string, n=3):
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

company_names = pd.Series(data['shipper_party_name'].unique()).dropna()
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(company_names)

# %%
from scipy.sparse import csr_matrix
import sparse_dot_topn.sparse_dot_topn as ct

def awesome_cossim_top(A, B, ntop, lower_bound=0):
    # force A and B as a CSR matrix.
    # If they have already been CSR, there is no overhead
    A = A.tocsr()
    B = B.tocsr()
    M, _ = A.shape
    _, N = B.shape
 
    idx_dtype = np.int32
 
    nnz_max = M*ntop
 
    indptr = np.zeros(M+1, dtype=idx_dtype)
    indices = np.zeros(nnz_max, dtype=idx_dtype)
    data = np.zeros(nnz_max, dtype=A.dtype)

    ct.sparse_dot_topn(
        M, N, np.asarray(A.indptr, dtype=idx_dtype),
        np.asarray(A.indices, dtype=idx_dtype),
        A.data,
        np.asarray(B.indptr, dtype=idx_dtype),
        np.asarray(B.indices, dtype=idx_dtype),
        B.data,
        ntop,
        lower_bound,
        indptr, indices, data)

    return csr_matrix((data,indices,indptr),shape=(M,N))

# %%
import time
t1 = time.time()
matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 10, 0.8)
t = time.time()-t1
print("SELFTIMED:", t)

# %%
def get_matches_df(sparse_matrix, name_vector, top=100):
    non_zeros = sparse_matrix.nonzero()
    
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    if top:
        nr_matches = top
    else:
        nr_matches = sparsecols.size
    
    left_side = np.empty([nr_matches], dtype=object)
    right_side = np.empty([nr_matches], dtype=object)
    similairity = np.zeros(nr_matches)
    
    for index in range(0, nr_matches):
        left_side[index] = name_vector[sparserows[index]]
        right_side[index] = name_vector[sparsecols[index]]
        similairity[index] = sparse_matrix.data[index]
    
    return pd.DataFrame({'left_side': left_side,
                          'right_side': right_side,
                           'similairity': similairity})

# %%
matches_df = get_matches_df(matches, company_names, top=100000)
matches_df.to_pickle('matches_df')
